# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
iris = sns.load_dataset('iris')
iris.head()  
## Tenemos todo un dataset con various features
X_iris = iris.drop('species', axis = 1)
y_iris = iris.species

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
## Ahora separamos entre train/test data
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, random_state = 1)

# %%
## seguimos receta dada porrr:

model = GaussianNB()  #instantiate a model
model.fit(Xtrain, ytrain)  #fit model
y_predict = model.predict(Xtest)  # predict on new data
y_predict
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'virginica',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'setosa', 'versicolor', 'setosa'], dtype='<U10')

# %%
from sklearn.metrics import accuracy_score

accuracy_score(ytest, y_predict)
# Out:
# 0.9736842105263158

# %% [markdown]
# NON-SUPERVISED
# REDUCTION OF ORDER
# using PRINCIPAL COMPONENT ANALYSIS (linear dimensionality reduction)

# %%
from sklearn.decomposition import PCA  # choose of model
model2 = PCA(n_components=2)  #instantiate the model with the hyperparameteres
model2.fit(X_iris)  # y is not specified 
X_2D = model2.transform(X_iris)  # transofmr the data to 2d

# %%
model2
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
iris['PCA1'] = X_2D[:,0]   # duda para el sensei
iris['PCA2'] = X_2D[:,1]
sns.lmplot('PCA1','PCA2', data=iris, hue = 'species', fit_reg = False)

# %% [markdown]
# UNSUPERVISED LEARNING
# GAUSSIAN MIXTURE MODEL

# %%
from sklearn.mixture import GMM  #choose a model
model_3 = GMM(n_components = 3, covariance_type = 'full')  # instantiate 
model_3.fit(X_iris)  #fit the model
y_gmm = model_3.predict(X_iris)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-75ad5af0463d> in <module>
# ----> 1 from sklearn.mixture import GMM  #choose a model
#       2 model_3 = GMM(n_components = 3, covariance_type = 'full')  # instantiate
#       3 model_3.fit(X_iris)  #fit the model
#       4 y_gmm = model_3.predict(X_iris)
#
# ImportError: cannot import name 'GMM' from 'sklearn.mixture' (c:\home\jupyter\venv\lib\site-packages\sklearn\mixture\__init__.py)
