# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data = {'area':[2600,3000,3200,3600,4000], 'price':[550000, 565000,610000,680000,725000]}
df = pd.DataFrame(data)

# %%
df
x=df.area
y=df.price
plt.xlabel('area(sqr ft)')
plt.ylabel('price')
plt.scatter(x,y, color='blue', marker='*')
plt.plot(x, reg.predict(df[['area']]), color = 'red')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
p ={'area':[100,1500,2300,3540,4120,4560,5490,3460,4750,2300,9000,8600,7100]}
area_predictions = pd.DataFrame(p)
area_predictions
# Out:
#     area
# 0    100
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
y_predicted = reg.predict(area_predictions)
y_predicted.tolist()
# Out:
# [194195.20547945198,
#  384297.9452054794,
#  492928.0821917808,
#  661304.794520548,
#  740061.6438356165,
#  799808.2191780822,
#  926090.7534246575,
#  650441.7808219178,
#  825607.8767123288,
#  492928.0821917808,
#  1402705.479452055,
#  1348390.4109589043,
#  1144708.904109589]
